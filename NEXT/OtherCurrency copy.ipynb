# %%
import pandas
from Funcations import *

# %%
from tradingview_ta import *
import time

symbol = TA_Handler(
    symbol='BNBUSDT',
    screener='crypto',
    exchange='binance',#binance
    interval= Interval.INTERVAL_15_MINUTES
)

print(symbol.get_analysis().indicators['RSI'])

# %%
from yfinance import *

# %%
import ta
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# دریافت داده تاریخی از Yahoo Finance
# symbol = "BTC-USD"
symbol = "GOLD"
data = yf.download(symbol, start="2024-01-15", end="2024-01-21",interval="1M")

# افزودن شاخص‌های تحلیل تکنیکال
data = ta.add_all_ta_features(data, open="Open", high="High", low="Low", close="Close", volume="Volume")
data2 = data.copy()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# c:\Users\mOsTaFa\AppData\Local\Programs\Python\Python311\Lib\site-packages\ta\trend.py:1030: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self._psar[i] = high2

# %%
data2
# Out:
#                           Open       High        Low      Close  Adj Close  \
# Datetime
# 2024-01-16 09:30:00  17.280001  17.309999  17.230000  17.260000  17.260000
# 2024-01-16 09:31:00  17.250000  17.299999  17.235001  17.235001  17.235001
# 2024-01-16 09:32:00  17.230000  17.230000  17.200001  17.219999  17.219999
# 2024-01-16 09:33:00  17.200001  17.250000  17.150000  17.160000  17.160000
# 2024-01-16 09:34:00  17.160000  17.160000  17.084999  17.100000  17.100000
# ...                        ...        ...        ...        ...        ...
# 2024-01-19 15:55:00  15.600000  15.610000  15.599000  15.610000  15.610000
# 2024-01-19 15:56:00  15.610000  15.610000  15.605000  15.605000  15.605000
# 2024-01-19 15:57:00  15.610000  15.615000  15.600100  15.615000  15.615000
# 2024-01-19 15:58:00  15.615000  15.620000  15.610000  15.610000  15.610000
# 2024-01-19 15:59:00  15.615000  15.620000  15.600000  15.600000  15.600000
#
# ...

# %%
import yfinance as yf
from datetime import datetime

# CREATE TICKER INSTANCE FOR AMAZON
amzn = yf.Ticker("AMZN")

# GET TODAYS DATE AND CONVERT IT TO A STRING WITH YYYY-MM-DD FORMAT (YFINANCE EXPECTS THAT FORMAT)
end_date = datetime.now().strftime('%Y-%m-%d')
amzn_hist = amzn.history(start='2023-10-01',end=end_date)
print(amzn_hist)

# %%
amzn_hist2 = amzn_hist.copy()

# %%
data2.reset_index(inplace=True)
data2['Datetime']
# Out:
# 0      2024-01-16 09:30:00
# 1      2024-01-16 09:31:00
# 2      2024-01-16 09:32:00
# 3      2024-01-16 09:33:00
# 4      2024-01-16 09:34:00
#                ...
# 1555   2024-01-19 15:55:00
# 1556   2024-01-19 15:56:00
# 1557   2024-01-19 15:57:00
# 1558   2024-01-19 15:58:00
# 1559   2024-01-19 15:59:00
# Name: Datetime, Length: 1560, dtype: datetime64[ns]

# %%
amzn_hist2.drop(['Dividends','Stock Splits'],inplace=True,axis=1)
amzn_hist2.reset_index(inplace=True)
amzn_hist2.rename(columns={'Date':'Datetime'},inplace = True)
amzn_hist2['Datetime'] = amzn_hist2['Datetime'].astype(str)
amzn_hist2['Datetime'] = amzn_hist2['Datetime'].apply(lambda x: x.rsplit('-', 1)[0]).tolist()

# %%
#  2024-01-16 09:30:00  -> 2024-01-19 15:59:00
path = "./PriceData/STOCKS/AAPL_1560_1M.csv" #APPLE 
# path = "./PriceData/STOCKS/META_1560_1M.csv" #META
# path = ...
data2 = pd.read_csv(path)

# %%
#  2024-01-16 09:30:00  -> 2024-01-19 15:59:00
path = "./PriceData/STOCKS/AAPL_1560_1M.csv" #APPLE 
# path = "./PriceData/STOCKS/META_1560_1M.csv" #META
# path = ...
data2 = pd.read_csv(path)

dataF = data2.copy()
dataF = pd.DataFrame(dataF,columns=['Datetime','Open','High','Low','Close','Volume'])
# dataF.to_csv(path)

dataF = signal_generator(dataF)
dataF = calculate_signals(dataF)

# dataF
result2 = BackTest(dataF,'Strategy 2')

print(result2.ShowResult())
# Out:
# Best Winrate : 66.66666666666666
# Best Waiting time : 7 minutes
# Good Signal : 28
# Bad Signal : 13

# %%
import os

# %%
import ta
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from Funcations import *
# دریافت داده تاریخی از Yahoo Finance
# symbol = "BTC-USD"
symbol = "SI=F" 
data = yf.download(symbol, start="2024-01-15", end="2024-01-21" , interval='1m')

# افزودن شاخص‌های تحلیل تکنیکال
data = ta.add_all_ta_features(data, open="Open", high="High", low="Low", close="Close", volume="Volume")
data.reset_index(inplace=True)
data2 = data.copy()

# # FUTURES
#  # 2024-01-16 09:30:00  -> 2024-01-19 15:59:00

# # STOCKS
# #  2024-01-16 09:30:00  -> 2024-01-19 15:59:00
# path = "./PriceData/STOCKS/AAPL_1560_1M.csv" #APPLE 
# path = "./PriceData/STOCKS/META_1560_1M.csv" #META

# # Crypto
# path = "./PriceData/CRYPTO/BTCUSDT_1500_5M.csv"
# path = "./PriceData/CRYPTO/BTCUSDT_1500_15M.csv"
# path = "./PriceData/CRYPTO/ETHUSD_1500_1d.csv"
# path = "./PriceData/CRYPTO/DOGEUSD_1000_15M.csv"


data2.to_csv("./PriceData/SILVER.csv")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# c:\Users\mOsTaFa\AppData\Local\Programs\Python\Python311\Lib\site-packages\ta\trend.py:1030: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self._psar[i] = high2

# %%
data2 = data.copy()

# %%
data2
# Out:
#                       Datetime       Open       High        Low      Close  \
# 0    2024-01-15 00:01:00-05:00  23.415001  23.415001  23.410000  23.415001
# 1    2024-01-15 00:02:00-05:00  23.415001  23.415001  23.415001  23.415001
# 2    2024-01-15 00:05:00-05:00  23.420000  23.420000  23.420000  23.420000
# 3    2024-01-15 00:06:00-05:00  23.420000  23.420000  23.415001  23.415001
# 4    2024-01-15 00:07:00-05:00  23.420000  23.420000  23.420000  23.420000
# ...                        ...        ...        ...        ...        ...
# 5993 2024-01-19 16:55:00-05:00  22.740000  22.745001  22.740000  22.745001
# 5994 2024-01-19 16:56:00-05:00  22.745001  22.750000  22.745001  22.750000
# 5995 2024-01-19 16:57:00-05:00  22.750000  22.750000  22.750000  22.750000
# 5996 2024-01-19 16:58:00-05:00  22.750000  22.754999  22.750000  22.750000
# 5997 2024-01-19 16:59:00-05:00  22.754999  22.754999  22.711000  22.750000
#
#       Adj Close  Volume   volume_adi  volume_obv  volume_cmf  ...  \
# ...

# %%
# path = './PriceData/SILVER.csv'

# data2 = pd.read_csv(path)

# data2.drop(['Unnamed: 0'],axis=1,inplace=True)
# data2.rename(columns = {'Date':"Datetime"},inplace=True)

# data2 = pd.DataFrame(data2,columns=['Datetime','Open','High','Low','Close','Volume'])

data2
# Out:
#      Datetime       Open       High        Low      Close  Volume
# 0     2024-01  23.415001  23.415001  23.410000  23.415001       0
# 1     2024-01  23.415001  23.415001  23.415001  23.415001       4
# 2     2024-01  23.420000  23.420000  23.420000  23.420000       2
# 3     2024-01  23.420000  23.420000  23.415001  23.415001       4
# 4     2024-01  23.420000  23.420000  23.420000  23.420000       5
# ...       ...        ...        ...        ...        ...     ...
# 5993  2024-01  22.740000  22.745001  22.740000  22.745001      19
# 5994  2024-01  22.745001  22.750000  22.745001  22.750000      20
# 5995  2024-01  22.750000  22.750000  22.750000  22.750000       6
# 5996  2024-01  22.750000  22.754999  22.750000  22.750000      28
# 5997  2024-01  22.754999  22.754999  22.711000  22.750000      15
#
# [5998 rows x 6 columns]

# %%
amzn_hist2 = data2
# amzn_hist2.drop(['Dividends','Stock Splits'],inplace=True,axis=1)
# amzn_hist2.reset_index(inplace=True)
# amzn_hist2.rename(columns={'Date':'Datetime'},inplace = True)
amzn_hist2['Datetime'] = amzn_hist2['Datetime'].astype(str)
amzn_hist2['Datetime'] = amzn_hist2['Datetime'].apply(lambda x: x.rsplit('-', 1)[0]).tolist()

# %%
amzn_hist2
# Out:
#                  Datetime       Open       High        Low      Close  \
# 0     2024-01-15 00:01:00  23.415001  23.415001  23.410000  23.415001
# 1     2024-01-15 00:02:00  23.415001  23.415001  23.415001  23.415001
# 2     2024-01-15 00:05:00  23.420000  23.420000  23.420000  23.420000
# 3     2024-01-15 00:06:00  23.420000  23.420000  23.415001  23.415001
# 4     2024-01-15 00:07:00  23.420000  23.420000  23.420000  23.420000
# ...                   ...        ...        ...        ...        ...
# 5993  2024-01-19 16:55:00  22.740000  22.745001  22.740000  22.745001
# 5994  2024-01-19 16:56:00  22.745001  22.750000  22.745001  22.750000
# 5995  2024-01-19 16:57:00  22.750000  22.750000  22.750000  22.750000
# 5996  2024-01-19 16:58:00  22.750000  22.754999  22.750000  22.750000
# 5997  2024-01-19 16:59:00  22.754999  22.754999  22.711000  22.750000
#
#       Adj Close  Volume   volume_adi  volume_obv  volume_cmf  ...  \
# ...

# %%
path = './PriceData/SILVER.csv'
amzn_hist2.to_csv(path)

# %%
data2 = pd.read_csv(path)
data2
# Out:
#       Unnamed: 0             Datetime       Open       High        Low  \
# 0              0  2024-01-15 00:01:00  23.415001  23.415001  23.410000
# 1              1  2024-01-15 00:02:00  23.415001  23.415001  23.415001
# 2              2  2024-01-15 00:05:00  23.420000  23.420000  23.420000
# 3              3  2024-01-15 00:06:00  23.420000  23.420000  23.415001
# 4              4  2024-01-15 00:07:00  23.420000  23.420000  23.420000
# ...          ...                  ...        ...        ...        ...
# 5993        5993  2024-01-19 16:55:00  22.740000  22.745001  22.740000
# 5994        5994  2024-01-19 16:56:00  22.745001  22.750000  22.745001
# 5995        5995  2024-01-19 16:57:00  22.750000  22.750000  22.750000
# 5996        5996  2024-01-19 16:58:00  22.750000  22.754999  22.750000
# 5997        5997  2024-01-19 16:59:00  22.754999  22.754999  22.711000
#
#           Close  Adj Close  Volume   volume_adi  volume_obv  ...  \
# ...

# %%
dataF = amzn_hist2.copy()
dataF = pd.DataFrame(dataF,columns=['Datetime','Open','High','Low','Close','Volume'])
# dataF.to_csv(path)

dataF = signal_generator(dataF)
dataF = calculate_signals(dataF)

result2 = BackTest(dataF,'Strategy 2')

print(result2.ShowResult())
# Out:
# Best Winrate : 55.55555555555556
# Best Waiting time : 2 minutes
# Good Signal : 20
# Bad Signal : 11
